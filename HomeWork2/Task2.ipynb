# %%
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
data = pd.read_csv('C:/Users/Len/Downloads/DATA-ANALYSYS_2-master (1)/DATA-ANALYSYS_2-master/Dataset/math_students.csv', delimiter=',')
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data[::2]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 8       GP   M   15       U     LE3       A     3     2  services     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
data[data['absences']%2==0]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
abMore10 = data[data['absences']>10]
abLess10 = data[data['absences']<=10]
if abMore10['G3'].mean()<abLess10['G3'].mean():
    print('true')
else: print('false')
# Out:
# true

# %%
dalcMore3 = data[data['Dalc']>3]
dalcLess3 = data[data['Dalc']<=3]
if dalcMore3['G3'].mean()<dalcLess3['G3'].mean():
    print('Dalc affects on G3')
else: print('Dalc does not affect on G3')
    
yes = data[data['higher']=='yes']
no = data[data['higher']=='no']
if yes['G3'].mean()<no['G3'].mean():
    print('Desire to learn affects on G3')
else: print('Desire to learn does not affect on G3')
    
yes = data[data['famsup']=='yes']
no = data[data['famsup']=='no']
if yes['G3'].mean()<no['G3'].mean():
    print('Support from family affects on G3')
else: print('Support from family does not affect on G3')
# Out:
# Dalc affects on G3
# Desire to learn does not affect on G3
# Support from family affects on G3

# %%
x = len(data[data['address']=='R'])/len(data)
p = round(x*100)
print('Actual for', p,  'percent')
# Out:
# Actual for 22 percent

# %%
newData = data.groupby('Pstatus')
newData.mean()
# Out:
#                age      Medu      Fedu  traveltime  studytime  failures  \
# Pstatus
# A        16.585366  3.146341  2.804878    1.390244   1.975610  0.341463
# T        16.709040  2.703390  2.488701    1.454802   2.042373  0.333333
#
#            famrel  freetime     goout      Dalc      Walc    health  absences  \
# Pstatus
# A        3.878049  3.121951  3.097561  1.560976  2.268293  3.463415  8.878049
# T        3.951977  3.248588  3.110169  1.471751  2.293785  3.564972  5.341808
#
#                 G1         G2         G3
# Pstatus
# A        11.073171  11.170732  11.195122
# T        10.889831  10.661017  10.324859
